# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x1 = np.array([2017, 2018, 2019, 2020, 2021])
y1 = np.array([5.3, 5.23, 5.01, 4.78, 4.72])     # Yam

x2 = np.array([2017, 2018, 2019, 2020, 2021])
y2 = np.array([1.83, 1.82, 1.78, 1.7, 1.71])    # Rice

x3 = np.array([2017, 2018, 2019, 2020, 2021])
y3 = np.array([2, 2.07, 1.97, 1.88, 1.85])      # Corn

x4 = np.array([2017, 2018, 2019, 2020, 2021])
y4 = np.array([1.19, 1.2, 1.21, 1.19, 1.25])    # Sorghum

x5 = np.array([2017, 2018, 2019, 2020, 2021])
y5 = np.array([0.77, 0.78, 0.78, 0.85, 0.8])   # Cowpea

x6 = np.array([2017, 2018, 2019, 2020, 2021])
y6 = np.array([1.09, 1.13, 1.18, 1.24, 1.25])  # Groundnut

x7 = np.array([2018, 2019, 2020, 2021])        # Soybean
y7 = np.array([1.13, 0.65, 0.68, 0.68])        # omitted an outlier entry

x8 = np.array([2017, 2018, 2019, 2020, 2021])
y8 = np.array([9.5, 9.6, 9.47, 9.34, 9.36])    # Cassava

x9 = np.array([2017, 2018, 2019, 2020, 2021])
y9 = np.array([2.61, 2.6, 2.58, 2.56, 2.54])   # Cocoyam

x10 = np.array([2017, 2018, 2019, 2020, 2021])
y10 = np.array([4.24, 0.68, 0.68, 0.68, 0.68]) # Tomato

new_list1 = range(math.floor(min(x1)), math.ceil(max(x1))+1)

plt.xticks(new_list1)

plt.title("Oyo, Nigeria Crop Yields (2017-2021)")
plt.xlabel("Year")
plt.ylabel("(Tons/HA)")

plt.plot(x1, y1, color = "red", label = "Yams")
plt.plot(x2, y2, color = "blue", label = "Rice")
plt.plot(x3, y3, color = "green", label = "Corn")
plt.plot(x4, y4, color = "red", label = "Sorghum")
plt.plot(x5, y5, color = "violet", label = "Cowpea")
plt.plot(x6, y6, color = "orange", label = "Groundnut")
plt.plot(x7, y7, color = "pink", label = "Soybean")
plt.plot(x8, y8, color = "black", label = "Cassava")
plt.plot(x9, y9, color = "grey", label = "Cocoyam")
#plt.plot(x10, y10, color = "teal", label = "Tomato")

plt.legend()

plt.show()

# %%
x = np.array([2017, 2018, 2019, 2020, 2021]) # years

y2 = np.array([99.58, 102.64, 104.19, 103.65, 108.6])                # Rice
y3 = np.array([296.06, 317.73, 311.49, 305.26, 315.82])              # Corn
y4 = np.array([58, 58.8, 59.78, 58.96, 64.9])                        # Sorghum
y5 = np.array([98.4, 128.69, 100.77, 101.42, 101.87])                # Cowpea
y6 = np.array([48.2, 50.76, 54.8, 59.16, 61.52])                     # Groundnut
y7 = np.array([21.03, 50.76, 26.06, 30.27, 33.34])                   # Soybean
y1 = np.array([1298.95, 1299.22, 1429.14, 1572.05, 1673.45])         # Yam
y8 = np.array([1775.9, 1829.81, 1805.9, 1782.3,	1823.47])            # Cassava
y9 = np.array([130.66, 130.92, 130.99, 131.06, 131.13])              # Cocoyam
y10 = np.array([36.36, 36.64, 36.92, 37.21, 37.21])                  # Tomato

new_list1 = range(math.floor(min(x)), math.ceil(max(x))+1)

plt.xticks(new_list1)

plt.title("Oyo, Nigeria Crop Production (2017-2021)")
plt.xlabel("Year")
plt.ylabel("(1k Ha)")

plt.plot(x, y1, color = "red", label = "Yams")
plt.plot(x, y2, color = "blue", label = "Rice")
plt.plot(x, y3, color = "green", label = "Maize")
plt.plot(x, y4, color = "red", label = "Sorghum")
plt.plot(x, y5, color = "violet", label = "Cowpea")
plt.plot(x, y6, color = "orange", label = "Groundnut")
plt.plot(x, y7, color = "pink", label = "Soybean")
plt.plot(x, y8, color = "black", label = "Cassava")
plt.plot(x, y9, color = "grey", label = "Cocoyam")
plt.plot(x, y10, color = "teal", label = "Tomato")

plt.legend()

plt.show()

# %%
import math
x = np.array([2017, 2018, 2019, 2020, 2021]) # years

y2 = np.array([54.52, 56.26, 58.58, 61.04, 63.37])        # Rice
y3 = np.array([134.63, 153.48, 158.6, 162.86, 170.86])    # Corn
y4 = np.array([48.71, 48.93, 49.28, 49.64, 51.7])         # Sorghum
y5 = np.array([128.27, 100.12, 128.81, 118.75, 127.31])   # Cowpea
y6 = np.array([44.13, 44.92, 46.33, 47.8, 49.17])         # Groundnut
y7 = np.array([35, 44.92, 40.05, 44.76, 49.13])           # Soybean
y1 = np.array([245.19, 248.32, 285.4, 329.19, 354.37])    # Yam
y8 = np.array([187, 190.58, 190.7, 190.82, 194.75])       # Cassava
y9 = np.array([50.14, 50.14, 50.78, 51.17, 51.56])        # Cocoyam
#y10 = np.array([8.57, 53.88, 54.18, 54.49, 54.49])        # Tomato

new_list1 = range(math.floor(min(x)), math.ceil(max(x))+1)

plt.xticks(new_list1)

plt.title("Oyo, Nigeria Land Area (2017-2021)")
plt.xlabel("Year")
plt.ylabel("(1k Ha)")

plt.plot(x, y1, color = "red", label = "Yams")
plt.plot(x, y2, color = "blue", label = "Rice")
plt.plot(x, y3, color = "green", label = "Maize")
plt.plot(x, y4, color = "red", label = "Sorghum")
plt.plot(x, y5, color = "violet", label = "Cowpea")
plt.plot(x, y6, color = "orange", label = "Groundnut")
plt.plot(x, y7, color = "pink", label = "Soybean")
plt.plot(x, y8, color = "black", label = "Cassava")
plt.plot(x, y9, color = "grey", label = "Cocoyam")
#plt.plot(x, y10, color = "teal", label = "Tomato")

plt.legend()

plt.show()
